# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing and Reading Combined Data

# %%
df = pd.read_csv('combined.csv')
df
# Out:
#        latitude   longitude  blk_no  postal_code               address  \
# 0      1.384021  103.837250     4.0     787082.0  174 ANG MO KIO AVE 4
# 1      1.384021  103.837250     4.0     787082.0  174 ANG MO KIO AVE 4
# 2      1.384021  103.837250     4.0     787082.0  174 ANG MO KIO AVE 4
# 3      1.384021  103.837250     4.0     787082.0  174 ANG MO KIO AVE 4
# 4      1.384021  103.837250     4.0     787082.0  174 ANG MO KIO AVE 4
# ...         ...         ...     ...          ...                   ...
# 4078  41.732265  -73.406393   478.0       6785.0          478 SEGAR RD
# 4079  41.732265  -73.406393   478.0       6785.0          478 SEGAR RD
# 4080  41.732265  -73.406393   478.0       6785.0          478 SEGAR RD
# 4081  41.732265  -73.406393   478.0       6785.0          478 SEGAR RD
# 4082  41.732265  -73.406393   478.0       6785.0          478 SEGAR RD
#
#           cbd_dist  min_dist_mrt    month           town flat_type block  \
# 0     1.127924e+04  1.132490e+02  2015-01     ANG MO KIO    3 ROOM   174
# 1     1.127924e+04  1.132490e+02  2015-12     ANG MO KIO    3 ROOM   174
# 2     1.127924e+04  1.132490e+02  2016-05     ANG MO KIO    3 ROOM   174
# 3     1.127924e+04  1.132490e+02  2016-06     ANG MO KIO    2 ROOM   174
# 4     1.127924e+04  1.132490e+02  2016-11     ANG MO KIO    3 ROOM   174
# ...            ...           ...      ...            ...       ...   ...
# 4078  1.523223e+07  1.521356e+07  2021-11  BUKIT PANJANG    4 ROOM   478
# 4079  1.523223e+07  1.521356e+07  2022-03  BUKIT PANJANG    4 ROOM   478
# 4080  1.523223e+07  1.521356e+07  2022-06  BUKIT PANJANG    5 ROOM   478
# 4081  1.523223e+07  1.521356e+07  2023-06  BUKIT PANJANG    5 ROOM   478
# 4082  1.523223e+07  1.521356e+07  2023-09  BUKIT PANJANG    5 ROOM   478
#
#            street_name storey_range  floor_area_sqm         flat_model  \
# 0     ANG MO KIO AVE 4     07 TO 09            60.0           Improved
# 1     ANG MO KIO AVE 4     10 TO 12            60.0           Improved
# 2     ANG MO KIO AVE 4     04 TO 06            69.0           Improved
# 3     ANG MO KIO AVE 4     07 TO 09            45.0           Improved
# 4     ANG MO KIO AVE 4     04 TO 06            61.0           Improved
# ...                ...          ...             ...                ...
# 4078          SEGAR RD     04 TO 06            92.0  Premium Apartment
# 4079          SEGAR RD     07 TO 09            92.0  Premium Apartment
# 4080          SEGAR RD     01 TO 03           112.0  Premium Apartment
# 4081          SEGAR RD     10 TO 12           110.0  Premium Apartment
# 4082          SEGAR RD     13 TO 15           110.0  Premium Apartment
#
#       lease_commence_date  resale_price     remaining_lease  \
# 0                    1986      255000.0                  70
# 1                    1986      275000.0                  69
# 2                    1986      310000.0                  68
# 3                    1986      253000.0                  68
# 4                    1986      290000.0                  68
# ...                   ...           ...                 ...
# 4078                 2003      425000.0  80 years 03 months
# 4079                 2003      435000.0  79 years 11 months
# 4080                 2003      450000.0  79 years 08 months
# 4081                 2003      562000.0  78 years 08 months
# 4082                 2003      555000.0  78 years 05 months
#
#       lease_remain_years
# 0                     62
# 1                     62
# 2                     62
# 3                     62
# 4                     62
# ...                  ...
# 4078                  79
# 4079                  79
# 4080                  79
# 4081                  79
# 4082                  79
#
# [4083 rows x 19 columns]

# %%
df.dtypes
# Out:
# latitude               float64
# longitude              float64
# blk_no                 float64
# postal_code            float64
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# lease_remain_years       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# latitude               0
# longitude              0
# blk_no                 0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# lease_remain_years     0
# dtype: int64

# %% [markdown]
# # Minor Data Preprocessing for Combined Data

# %%
import statistics

def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#        latitude   longitude  blk_no  postal_code               address  \
# 0      1.384021  103.837250     4.0     787082.0  174 ANG MO KIO AVE 4
# 1      1.384021  103.837250     4.0     787082.0  174 ANG MO KIO AVE 4
# 2      1.384021  103.837250     4.0     787082.0  174 ANG MO KIO AVE 4
# 3      1.384021  103.837250     4.0     787082.0  174 ANG MO KIO AVE 4
# 4      1.384021  103.837250     4.0     787082.0  174 ANG MO KIO AVE 4
# ...         ...         ...     ...          ...                   ...
# 4078  41.732265  -73.406393   478.0       6785.0          478 SEGAR RD
# 4079  41.732265  -73.406393   478.0       6785.0          478 SEGAR RD
# 4080  41.732265  -73.406393   478.0       6785.0          478 SEGAR RD
# 4081  41.732265  -73.406393   478.0       6785.0          478 SEGAR RD
# 4082  41.732265  -73.406393   478.0       6785.0          478 SEGAR RD
#
#           cbd_dist  min_dist_mrt    month           town flat_type block  \
# 0     1.127924e+04  1.132490e+02  2015-01     ANG MO KIO    3 ROOM   174
# 1     1.127924e+04  1.132490e+02  2015-12     ANG MO KIO    3 ROOM   174
# 2     1.127924e+04  1.132490e+02  2016-05     ANG MO KIO    3 ROOM   174
# 3     1.127924e+04  1.132490e+02  2016-06     ANG MO KIO    2 ROOM   174
# 4     1.127924e+04  1.132490e+02  2016-11     ANG MO KIO    3 ROOM   174
# ...            ...           ...      ...            ...       ...   ...
# 4078  1.523223e+07  1.521356e+07  2021-11  BUKIT PANJANG    4 ROOM   478
# 4079  1.523223e+07  1.521356e+07  2022-03  BUKIT PANJANG    4 ROOM   478
# 4080  1.523223e+07  1.521356e+07  2022-06  BUKIT PANJANG    5 ROOM   478
# 4081  1.523223e+07  1.521356e+07  2023-06  BUKIT PANJANG    5 ROOM   478
# 4082  1.523223e+07  1.521356e+07  2023-09  BUKIT PANJANG    5 ROOM   478
#
#            street_name storey_range  floor_area_sqm         flat_model  \
# 0     ANG MO KIO AVE 4     07 TO 09            60.0           Improved
# 1     ANG MO KIO AVE 4     10 TO 12            60.0           Improved
# 2     ANG MO KIO AVE 4     04 TO 06            69.0           Improved
# 3     ANG MO KIO AVE 4     07 TO 09            45.0           Improved
# 4     ANG MO KIO AVE 4     04 TO 06            61.0           Improved
# ...                ...          ...             ...                ...
# 4078          SEGAR RD     04 TO 06            92.0  Premium Apartment
# 4079          SEGAR RD     07 TO 09            92.0  Premium Apartment
# 4080          SEGAR RD     01 TO 03           112.0  Premium Apartment
# 4081          SEGAR RD     10 TO 12           110.0  Premium Apartment
# 4082          SEGAR RD     13 TO 15           110.0  Premium Apartment
#
#       lease_commence_date  resale_price     remaining_lease  \
# 0                    1986      255000.0                  70
# 1                    1986      275000.0                  69
# 2                    1986      310000.0                  68
# 3                    1986      253000.0                  68
# 4                    1986      290000.0                  68
# ...                   ...           ...                 ...
# 4078                 2003      425000.0  80 years 03 months
# 4079                 2003      435000.0  79 years 11 months
# 4080                 2003      450000.0  79 years 08 months
# 4081                 2003      562000.0  78 years 08 months
# 4082                 2003      555000.0  78 years 05 months
#
#       lease_remain_years  storey_median
# 0                     62            8.0
# 1                     62           11.0
# 2                     62            5.0
# 3                     62            8.0
# 4                     62            5.0
# ...                  ...            ...
# 4078                  79            5.0
# 4079                  79            8.0
# 4080                  79            2.0
# 4081                  79           11.0
# 4082                  79           14.0
#
# [4083 rows x 20 columns]

# %%
scope_df = df[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']]
scope_df
# Out:
#           cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0     1.127924e+04  1.132490e+02            60.0                  62
# 1     1.127924e+04  1.132490e+02            60.0                  62
# 2     1.127924e+04  1.132490e+02            69.0                  62
# 3     1.127924e+04  1.132490e+02            45.0                  62
# 4     1.127924e+04  1.132490e+02            61.0                  62
# ...            ...           ...             ...                 ...
# 4078  1.523223e+07  1.521356e+07            92.0                  79
# 4079  1.523223e+07  1.521356e+07            92.0                  79
# 4080  1.523223e+07  1.521356e+07           112.0                  79
# 4081  1.523223e+07  1.521356e+07           110.0                  79
# 4082  1.523223e+07  1.521356e+07           110.0                  79
#
#       storey_median  resale_price
# 0               8.0      255000.0
# 1              11.0      275000.0
# 2               5.0      310000.0
# 3               8.0      253000.0
# 4               5.0      290000.0
# ...             ...           ...
# 4078            5.0      425000.0
# 4079            8.0      435000.0
# 4080            2.0      450000.0
# 4081           11.0      562000.0
# 4082           14.0      555000.0
#
# [4083 rows x 6 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#           cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0     1.127924e+04  1.132490e+02            60.0                  62
# 1     1.127924e+04  1.132490e+02            60.0                  62
# 2     1.127924e+04  1.132490e+02            69.0                  62
# 3     1.127924e+04  1.132490e+02            45.0                  62
# 4     1.127924e+04  1.132490e+02            61.0                  62
# ...            ...           ...             ...                 ...
# 4078  1.523223e+07  1.521356e+07            92.0                  79
# 4079  1.523223e+07  1.521356e+07            92.0                  79
# 4080  1.523223e+07  1.521356e+07           112.0                  79
# 4081  1.523223e+07  1.521356e+07           110.0                  79
# 4082  1.523223e+07  1.521356e+07           110.0                  79
#
#       storey_median  resale_price
# 0               8.0      255000.0
# 1              11.0      275000.0
# 2               5.0      310000.0
# 3               8.0      253000.0
# 4               5.0      290000.0
# ...             ...           ...
# 4078            5.0      425000.0
# 4079            8.0      435000.0
# 4080            2.0      450000.0
# 4081           11.0      562000.0
# 4082           14.0      555000.0
#
# [3926 rows x 6 columns]

# %% [markdown]
# # Checking and Handling for Skewness in the Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %%
df1 = scope_df

# %%
# Apply a logarithmic transformation to the required columns only.
# One need to apply it and check, in some cases it will handle the skewness, and in other cases it might not have a great 
                                                                # effect on the data, so no need to apply for that columns
    
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %% [markdown]
# # Visualization among different columns using Correlation Matrix

# %%
import seaborn as sns

corrMatrix = df1.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %% [markdown]
# # Encoding Data

# %%
from sklearn.preprocessing import StandardScaler

X=df1[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median']]
y=df1['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#              0         1         2         3         4
# 0    -0.141810 -0.143191 -1.610193 -0.212882  0.161512
# 1    -0.141810 -0.143191 -1.610193 -0.212882  0.595267
# 2    -0.141810 -0.143191 -1.032123 -0.212882 -0.478664
# 3    -0.141810 -0.143191 -2.800076 -0.212882  0.161512
# 4    -0.141810 -0.143191 -1.541826 -0.212882 -0.478664
# ...        ...       ...       ...       ...       ...
# 3921  7.975816  7.975788  0.157760  1.389845 -0.478664
# 3922  7.975816  7.975788  0.157760  1.389845  0.161512
# 3923  7.975816  7.975788  0.971374  1.389845 -1.726712
# 3924  7.975816  7.975788  0.896848  1.389845  0.595267
# 3925  7.975816  7.975788  0.896848  1.389845  0.923746
#
# [3926 rows x 5 columns]

# %% [markdown]
# # Splitting the Data for Training and Testing Purposes

# %%
from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
# Out:
# Best hyperparameters: {'max_depth': 22, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
#
# Mean squared error: 0.01512034201429928
# Mean Absolute Error 0.09493760603761821
# Root Mean squared error: 0.12296479989939918
#
# R-squared: 0.8815469354677642

# %% [markdown]
# # Testing Our Trained Model (Decision Tree Regressor)

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :5])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)
# Out:
# 242573.9512700722

# %%
# Saving the model
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
